# %%
import requests

url = "https://en.wikipedia.org/wiki/London"  
response = requests.get(url)
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, "html.parser")
text = soup.text

# %%
text
# Out:
# '\n\n\n\nLondon - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\n Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1Toponymy\n\n\n\n\n\n\n\n2History\n\n\n\nToggle History subsection\n\n\n\n\n\n2.1Prehistory\n\n\n\n\n\n\n\n2.2Roman London\n\n\n\n\n\n\n\n2.3Anglo-Saxon and Viking-period London\n\n\n\n\n\n\n\n2.4Middle Ages\n\n\n\n\n\n\n\n2.5Early modern\n\n\n\n\n\n\n\n2.6Late modern and contemporary\n\n\n\n\n\n\n\n\n\n3Administration\n\n\n\nToggle Administration subsection\n\n\n\n\n\n3.1Local government\n\n\n\n\n\n\n\n3.2National government\n\n\n\n\n\n\n\n3.3Policing and crime\n\n\n\n\n\n\n\n\n\n4Geography\n\n\n\nToggle Geography subsection\n\n\n\n\n\n4.1Scope\n\n\n\n\n\n\n\n4.2Status\n\n\n\n\n\n\n\n4.3Topography\n\n\n\n\n\n\n\n4.4Climate\n\n\n\n\n\n\n\n4.5Areas\n\n\n\n\n\n\n\n4.6Architecture\n\n\n\n\n\n\n\n4.7Natural history\n\n\n\n\n\n\n\n\n\n5Demography\n\n\n\nToggle Demography subsection\n\n\n\n\n\n5.1Age structure and median age\n\n\n\n\n\n\n\n5.2Country of birth\n\n\n\n\n\n\n\n5.3Ethnic groups\n\n\n\n\n\n\n\n5.4Languages\n\n\n\n\n\n\n\n5.5Religion\n\n\n\n\n\n\n\n5.6Accents\n\n\n\n\n\n\n\n\n\n6Economy\n\n\n\nToggle Economy subsection\n\n\n\n\n\n6.1City of London\n\n\n\n\n\n\n\n6.2Media and technology\n\n\n\n\n\n\n\n6.3Tourism\n\n\n\n\n\n\n\n\n\n7Transport\n\n\n\nToggle Transport subsection\n\n\n\n\n\n7.1Aviation\n\n\n\n\n\n\n\n7.2Rail\n\n\n\n\n\n7.2.1Underground and DLR\n\n\n\n\n\n\n\n7.2.2Suburban\n\n\n\n\n\n\n\n7.2.3Inter-city and international\n\n\n\n\n\n\n\n\n\n7.3Buses, coaches and trams\n\n\n\n\n\n\n\n7.4Cable car\n\n\n\n\n\n\n\n7.5Cycling\n\n\n\n\n\n\n\n7.6Port and river boats\n\n\n\n\n\n\n\n7.7Roads\n\n\n\n\n\n\n\n\n\n8Education\n\n\n\nToggle Education subsection\n\n\n\n\n\n8.1Tertiary education\n\n\n\n\n\n\n\n8.2Primary and secondary education\n\n\n\n\n\n\n\n8.3Royal Observatory, Greenwich and learned societies\n\n\n\n\n\n\n\n\n\n9Culture\n\n\n\nToggle Culture subsection\n\n\n\n\n\n9.1Leisure and entertainment\n\n\n\n\n\n\n\n9.2LGBT scene\n\n\n\n\n\n\n\n9.3Literature, film and television\n\n\n\n\n\n\n\n9.4Museums, art galleries and libraries\n\n\n\n\n\n\n\n9.5Music\n\n\n\n\n\n\n\n\n\n10Recreation\n\n\n\nToggle Recreation subsection\n\n\n\n\n\n10.1Parks and open spaces\n\n\n\n\n\n\n\n10.2Walking\n\n\n\n\n\n\n\n\n\n11Sport\n\n\n\n\n\n\n\n12Notable people\n\n\n\n\n\n\n\n13See also\n\n\n\n\n\n\n\n14Notes\n\n\n\n\n\n\n\n15References\n\n\n\nToggle References subsection\n\n\n\n\n\n15.1Bibliography\n\n\n\n\n\n\n\n\n\n16External links\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nToggle the table of contents\n\n\n\n\n\n\n\nLondon\n\n\n\n270 languages\n\n\n\n\nAcèhАдыгэбзэАдыгабзэAfrikaansAlemannischአማርኛAnarâškielâअंगिकाÆngliscАԥсшәаالعربيةAragonésܐܪܡܝܐԱրեւմտահայերէնArmãneashtiArpetanঅসমীয়াAsturianuअवधीAvañe\'ẽАварAymar aruAzərbaycancaتۆرکجهBasa BaliBamanankanবাংলাBân-lâm-gúBasa BanyumasanБашҡортсаБеларускаяБеларуская (тарашкевіца)भोजपुरीBikol CentralBislamaБългарскиBoarischབོད་ཡིགBosanskiBrezhonegБуряадCatalàЧӑвашлаCebuanoČeštinaChavacano de ZamboangaChi-ChewaChiShonaChiTumbukaCorsuCymraegDanskالدارجةDavvisámegiellaDeitschDeutschDiné bizaadDolnoserbskiडोटेलीEestiΕλληνικάEmiliàn e rumagnòlЭрзяньEspañolEsperantoEstremeñuEuskaraEʋegbeفارسیFiji HindiFøroysktFrançaisFryskFulfuldeFurlanGaeilgeGaelgGagauzGàidhligGalegoГӀалгӀай贛語گیلکیગુજરાતી𐌲𐌿𐍄𐌹𐍃𐌺गोंयची कोंकणी /  ...

# %%
len(text)
# Out:
# 189633

# %%
import re
import numpy as np
import nltk
import spacy
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
cleaned_text = re.sub(r"[^a-zA-Z]" , " " , text)
cleaned_text = re.sub(r"\s+" , " " , cleaned_text )

# %%
len(cleaned_text)
# Out:
# 163777

# %%
cleaned_text
# Out:
# ' London Wikipedia Jump to content Main menu Main menu move to sidebar hide Navigation Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate Contribute HelpLearn to editCommunity portalRecent changesUpload file Search Search Create account Log in Personal tools Create account Log in Pages for logged out editors learn more ContributionsTalk Contents move to sidebar hide Top Toponymy History Toggle History subsection Prehistory Roman London Anglo Saxon and Viking period London Middle Ages Early modern Late modern and contemporary Administration Toggle Administration subsection Local government National government Policing and crime Geography Toggle Geography subsection Scope Status Topography Climate Areas Architecture Natural history Demography Toggle Demography subsection Age structure and median age Country of birth Ethnic groups Languages Religion Accents Economy Toggle Economy subsection City of London Media and technology Tourism Transport Toggle Transport subsection Aviation Rail Underground and DLR Suburban Inter city and international Buses coaches and trams Cable car Cycling Port and river boats Roads Education Toggle Education subsection Tertiary education Primary and secondary education Royal Observatory Greenwich and learned societies Culture Toggle Culture subsection Leisure and entertainment LGBT scene Literature film and television Museums art galleries and libraries Music Recreation Toggle Recreation subsection Parks and open spaces Walking Sport Notable people See also Notes References Toggle References subsection Bibliography External links Toggle the table of contents London languages Ac h AfrikaansAlemannisch Anar kiel nglisc Aragon s Arm neashtiArpetan Asturianu Ava e Aymar aruAz rbaycanca Basa BaliBamanankan B n l m g Basa Banyumasan Bikol CentralBislama Boarisch BosanskiBrezhoneg Catal Cebuano e tinaChavacano de ZamboangaChi ChewaChiShonaChiTumbukaCorsuCymraegDansk Davvis megiellaDeitschDeutschDin bizaadDolnoserbski Eesti Emili n e rumagn l Espa olEsperantoEstreme uEuskaraE egbe Fiji HindiF roysktFran aisFryskFulfuldeFurlanGaeilgeGaelgGagauzG idhligGalego G ychi Konknni Hak k ng HausaHawai i HornjoserbsceHrvatskiIdoIgboIlokanoBahasa IndonesiaInterlinguaInterlingue IsiZulu slenskaItaliano JawaKab y Kalaallisut Kasz bsczi KernowekKiswahili KotavaKrey l ayisyenKriy l gwiyannenKurd LadinLadino LatinaLatvie uL tzebuergesch Lietuvi LigureLimburgsLing laLingua Franca NovaLivvinkarjalaLa lojban LombardMagyar Malagasy MaltiM ori Bahasa MelayuMinangkabau M ng d ng ng Mirand s Na Vosa VakavitiNederlandsNedersaksies Napulitano NordfriiskNorfuk PitkernNorsk bokm lNorsk nynorskNouormandNovialOccitan OromooO zbekcha Pangcah Papiamentu Patois PicardPiemont isPinayuananTok PisinPlattd tschPolski Portugu sQaraqalpaqshaQ r mtatarcaRipoarischRom n Romani hibRumantschRuna Simi SakizayaGagana Samoa SarduScotsSeelterskSesothoShqipSicilianu Simple English Sloven inaSloven ina l nskiSoomaaliga Sranantongo srpskiSrpskohrvatski SundaSuomiSvenskaTagalog Tacl itTaqbaylitTarand ne tatar a Tetun Lea faka Tonga T rk eT rkmen eTwiTyap UyghurcheVahcuenghV netoVeps n kel Ti ng Vi tVolap kV roWalon West VlamsWinarayWolof Yor b ZazakiZe uws emait ka Tol i Edit links ArticleTalk English ReadView sourceView history Tools Tools move to sidebar hide Actions ReadView sourceView history General What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationCite this pageGet shortened URLDownload QR codeWikidata item Print export Download as PDFPrintable version In other projects Wikimedia CommonsWikibooksWikinewsWikiquoteWikivoyage Coordinates N W N W From Wikipedia the free encyclopedia Capital city of England and the United Kingdom This article is about the capital city of England and the United Kingdom For other uses see London disambiguation Capital city in EnglandLondonCapital cityRiver Thames and Tower Bridge with The Shard and Southwark left Tower of London and City of London right London EyeNelso ...

# %%
normalized_text = cleaned_text.lower()
normalized_text
# Out:
# ' london wikipedia jump to content main menu main menu move to sidebar hide navigation main pagecontentscurrent eventsrandom articleabout wikipediacontact usdonate contribute helplearn to editcommunity portalrecent changesupload file search search create account log in personal tools create account log in pages for logged out editors learn more contributionstalk contents move to sidebar hide top toponymy history toggle history subsection prehistory roman london anglo saxon and viking period london middle ages early modern late modern and contemporary administration toggle administration subsection local government national government policing and crime geography toggle geography subsection scope status topography climate areas architecture natural history demography toggle demography subsection age structure and median age country of birth ethnic groups languages religion accents economy toggle economy subsection city of london media and technology tourism transport toggle transport subsection aviation rail underground and dlr suburban inter city and international buses coaches and trams cable car cycling port and river boats roads education toggle education subsection tertiary education primary and secondary education royal observatory greenwich and learned societies culture toggle culture subsection leisure and entertainment lgbt scene literature film and television museums art galleries and libraries music recreation toggle recreation subsection parks and open spaces walking sport notable people see also notes references toggle references subsection bibliography external links toggle the table of contents london languages ac h afrikaansalemannisch anar kiel nglisc aragon s arm neashtiarpetan asturianu ava e aymar aruaz rbaycanca basa balibamanankan b n l m g basa banyumasan bikol centralbislama boarisch bosanskibrezhoneg catal cebuano e tinachavacano de zamboangachi chewachishonachitumbukacorsucymraegdansk davvis megielladeitschdeutschdin bizaaddolnoserbski eesti emili n e rumagn l espa olesperantoestreme ueuskarae egbe fiji hindif roysktfran aisfryskfulfuldefurlangaeilgegaelggagauzg idhliggalego g ychi konknni hak k ng hausahawai i hornjoserbscehrvatskiidoigboilokanobahasa indonesiainterlinguainterlingue isizulu slenskaitaliano jawakab y kalaallisut kasz bsczi kernowekkiswahili kotavakrey l ayisyenkriy l gwiyannenkurd ladinladino latinalatvie ul tzebuergesch lietuvi ligurelimburgsling lalingua franca novalivvinkarjalala lojban lombardmagyar malagasy maltim ori bahasa melayuminangkabau m ng d ng ng mirand s na vosa vakavitinederlandsnedersaksies napulitano nordfriisknorfuk pitkernnorsk bokm lnorsk nynorsknouormandnovialoccitan oromooo zbekcha pangcah papiamentu patois picardpiemont ispinayuanantok pisinplattd tschpolski portugu sqaraqalpaqshaq r mtatarcaripoarischrom n romani hibrumantschruna simi sakizayagagana samoa sarduscotsseeltersksesothoshqipsicilianu simple english sloven inasloven ina l nskisoomaaliga sranantongo srpskisrpskohrvatski sundasuomisvenskatagalog tacl ittaqbaylittarand ne tatar a tetun lea faka tonga t rk et rkmen etwityap uyghurchevahcuenghv netoveps n kel ti ng vi tvolap kv rowalon west vlamswinaraywolof yor b zazakize uws emait ka tol i edit links articletalk english readview sourceview history tools tools move to sidebar hide actions readview sourceview history general what links hererelated changesupload filespecial pagespermanent linkpage informationcite this pageget shortened urldownload qr codewikidata item print export download as pdfprintable version in other projects wikimedia commonswikibookswikinewswikiquotewikivoyage coordinates n w n w from wikipedia the free encyclopedia capital city of england and the united kingdom this article is about the capital city of england and the united kingdom for other uses see london disambiguation capital city in englandlondoncapital cityriver thames and tower bridge with the shard and southwark left tower of london and city of london right london eyenelso ...

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
tokens = normalized_text.split()

lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(i) for i in tokens]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words("english"))
filtered_tokens = [token for token in lemmatized_tokens if token not in stop_words]

#filtered_tokens = [token for token in lemmatized_tokens if token not in stop_words]

# %%
filtered_tokens
# Out:
# ['london',
#  'wikipedia',
#  'jump',
#  'content',
#  'main',
#  'menu',
#  'main',
#  'menu',
#  'move',
#  'sidebar',
#  'hide',
#  'navigation',
#  'main',
#  'pagecontentscurrent',
#  'eventsrandom',
#  'articleabout',
#  'wikipediacontact',
#  'usdonate',
#  'contribute',
#  'helplearn',
#  'editcommunity',
#  'portalrecent',
#  'changesupload',
#  'file',
#  'search',
#  'search',
#  'create',
#  'account',
#  'log',
#  'personal',
#  'tool',
#  'create',
#  'account',
#  'log',
#  'page',
#  'logged',
#  'editor',
#  'learn',
#  'contributionstalk',
#  'content',
#  'move',
#  'sidebar',
#  'hide',
#  'top',
#  'toponymy',
#  'history',
#  'toggle',
#  'history',
#  'subsection',
#  'prehistory',
#  'roman',
#  'london',
#  'anglo',
#  'saxon',
#  'viking',
#  'period',
#  'london',
#  'middle',
#  'age',
#  'early',
#  'modern',
#  'late',
#  'modern',
#  'contemporary',
#  'administration',
#  'toggle',
#  'administration',
#  'subsection',
#  'local',
#  'government',
#  'national',
#  'government',
#  'policing',
#  'crime',
#  'geography',
#  'toggle',
#  'geography',
#  'subsection',
#  'scope',
#  'status',
#  'topography',
#  'climate',
#  'area',
#  'architecture',
#  'natural',
#  'history',
#  'demography',
#  'toggle',
#  'demography',
#  'subsection',
#  'age',
#  'structure',
#  'median',
#  'age',
#  'country',
#  'birth',
#  'ethnic',
#  'group',
#  'language',
#  'religion',
#  'accent',
#  'economy',
#  'toggle',
#  'economy',
#  'subsection',
#  'city',
#  'london',
#  'medium',
#  'technology',
#  'tourism',
#  'transport',
#  'toggle',
#  'transport',
#  'subsection',
#  'aviation',
#  'rail',
#  'underground',
#  'dlr',
#  'suburban',
#  'inter',
#  'city',
#  'international',
#  'bus',
#  'coach',
#  'tram',
#  'cable',
#  'car',
#  'cycling',
#  'port',
#  'river',
#  'boat',
#  'road',
#  'education',
#  'toggle',
#  'education',
#  'subsection',
#  'tertiary',
#  'education',
#  'primary',
#  'secondary',
#  'education',
#  'royal',
#  'observatory',
#  'greenwich',
#  'learned',
#  'society',
#  'culture',
#  'toggle',
#  'culture',
#  'subsection',
#  'leisure',
#  'entertainment',
#  'lgbt',
#  'scene',
#  'literature',
#  'film',
#  'television',
#  'museum',
#  'art',
#  'gallery',
#  'library',
#  'music',
#  'recreation',
#  'toggle',
#  'recreation',
#  'subsection',
#  'park',
#  'open',
#  'space',
#  'walking',
#  'sport',
#  'notable',
#  'people',
#  'see',
#  'also',
#  'note',
#  'reference',
#  'toggle',
#  'reference',
#  'subsection',
#  'bibliography',
#  'external',
#  'link',
#  'toggle',
#  'table',
#  'content',
#  'london',
#  'language',
#  'ac',
#  'h',
#  'afrikaansalemannisch',
#  'anar',
#  'kiel',
#  'nglisc',
#  'aragon',
#  'arm',
#  'neashtiarpetan',
#  'asturianu',
#  'ava',
#  'e',
#  'aymar',
#  'aruaz',
#  'rbaycanca',
#  'basa',
#  'balibamanankan',
#  'b',
#  'n',
#  'l',
#  'g',
#  'basa',
#  'banyumasan',
#  'bikol',
#  'centralbislama',
#  'boarisch',
#  'bosanskibrezhoneg',
#  'catal',
#  'cebuano',
#  'e',
#  'tinachavacano',
#  'de',
#  'zamboangachi',
#  'chewachishonachitumbukacorsucymraegdansk',
#  'davvis',
#  'megielladeitschdeutschdin',
#  'bizaaddolnoserbski',
#  'eesti',
#  'emili',
#  'n',
#  'e',
#  'rumagn',
#  'l',
#  'espa',
#  'olesperantoestreme',
#  'ueuskarae',
#  'egbe',
#  'fiji',
#  'hindif',
#  'roysktfran',
#  'aisfryskfulfuldefurlangaeilgegaelggagauzg',
#  'idhliggalego',
#  'g',
#  'ychi',
#  'konknni',
#  'hak',
#  'k',
#  'ng',
#  'hausahawai',
#  'hornjoserbscehrvatskiidoigboilokanobahasa',
#  'indonesiainterlinguainterlingue',
#  'isizulu',
#  'slenskaitaliano',
#  'jawakab',
#  'kalaallisut',
#  'kasz',
#  'bsczi',
#  'kernowekkiswahili',
#  'kotavakrey',
#  'l',
#  'ayisyenkriy',
#  'l',
#  'gwiyannenkurd',
#  'ladinladino',
#  'latinalatvie',
#  'ul',
#  'tzebuergesch',
#  'lietuvi',
#  'ligurelimburgsling',
#  'lalingua',
#  'franca',
#  'novalivvinkarjalala',
#  'lojban',
#  'lombardmagyar',
#  'malagasy',
#  'maltim',
#  'ori',
#  'bahasa',
#  'melayuminangkabau',
#  'ng',
#  'ng',
#  'ng',
#  'mirand',
#  'na',
#  'vosa',
#  'vakavitinederlandsnedersaksies',
#  'napulitano',
#  'nordfriisknorfuk',
#  'pitkernnorsk',
#  'bokm',
#  'lnorsk',
#  'nynorsknouormandnovialoccitan',
#  'oromooo',
#  'zbekcha',
#  'pangcah',
#  'papiamentu',
#  'patois',
#  'picardpiemont',
#  'ispinayuanantok',
#  'pisinplattd',
#  'tschpolski',
#  'portugu',
#  'sqaraqalpaqshaq',
#  'r',
#  'mtatarcaripoarischrom',
#  'n',
#  'romani',
#  'hibrumantschruna',
#  'simi',
#  'sakizayagagana',
#  'samoa',
#  'sarduscotsseeltersksesothoshqipsicilianu',
#  'simple',
#  'english',
#  'sloven',
#  'inasloven',
#  'ina',
#  'l',
#  'nskisoomaaliga',
#  'sranantongo',
#  'srpskisrpskohrvatski',
#  'sundasuomisvenskatagalog',
#  'tacl',
#  'ittaqbaylittarand',
#  'ne',
#  'tatar',
#  'tetun',
#  'lea',
#  'faka',
#  'tonga',
#  'rk',
#  'et',
#  'rkmen',
#  'etwityap',
#  'uyghurchevahcuenghv',
#  'netoveps',
#  'n',
#  'kel',
#  'ti',
#  'ng',
#  'vi',
#  'tvolap',
#  'kv',
#  'rowalon',
#  'west',
#  'vlamswinaraywolof',
#  'yor',
#  'b',
#  'zazakize',
#  'uws',
#  'emait',
#  'ka',
#  'tol',
#  'edit',
#  'link',
#  'articletalk',
#  'english',
#  'readview',
#  'sourceview',
#  'history',
#  'tool',
#  'tool',
#  'move',
#  'sidebar',
#  'hide',
#  'action',
#  'readview',
#  'sourceview',
#  'history',
#  'general',
#  'link',
#  'hererelated',
#  'changesupload',
#  'filespecial',
#  'pagespermanent',
#  'linkpage',
#  'informationcite',
#  'pageget',
#  'shortened',
#  'urldownload',
#  'qr',
#  'codewikidata',
#  'item',
#  'print',
#  'export',
#  'download',
#  'pdfprintable',
#  'version',
#  'project',
#  'wikimedia',
#  'commonswikibookswikinewswikiquotewikivoyage',
#  'coordinate',
#  'n',
#  'w',
#  'n',
#  'w',
#  'wikipedia',
#  'free',
#  'encyclopedia',
#  'capital',
#  'city',
#  'england',
#  'united',
#  'kingdom',
#  'article',
#  'capital',
#  'city',
#  'england',
#  'united',
#  'kingdom',
#  'us',
#  'see',
#  'london',
#  'disambiguation',
#  'capital',
#  'city',
#  'englandlondoncapital',
#  'cityriver',
#  'thames',
#  'tower',
#  'bridge',
#  'shard',
#  'southwark',
#  'left',
#  'tower',
#  'london',
#  'city',
#  'london',
#  'right',
#  'london',
#  'eyenelson',
#  'columnst',
#  'paul',
#  'spiccadilly',
#  'circuscanary',
#  'wharfpalace',
#  'westminster',
#  'big',
#  'ben',
#  'right',
#  'londonlocation',
#  'within',
#  'united',
#  'kingdomshow',
#  'map',
#  'united',
#  'kingdomlondonlocation',
#  'within',
#  'englandshow',
#  'map',
#  'englandlondonlocation',
#  'within',
#  'europeshow',
#  'map',
#  'europelondonlondon',
#  'earth',
#  'show',
#  'map',
#  'earthcoordinates',
#  'n',
#  'w',
#  'n',
#  'w',
#  'sovereign',
#  'stateunited',
#  'kingdomcountryenglandregionlondon',
#  'greater',
#  'london',
#  'ceremonial',
#  'countiesgreater',
#  'london',
#  'ceremonial',
#  'county',
#  'city',
#  'londonlocal',
#  'government',
#  'district',
#  'london',
#  'boroughsand',
#  'city',
#  'londonsettled',
#  'romansad',
#  'year',
#  'ago',
#  'londiniumgovernment',
#  'typeexecutive',
#  'mayoralty',
#  'deliberative',
#  'assembly',
#  'bodygreater',
#  'london',
#  'authority',
#  'mayor',
#  'sadiq',
#  'khan',
#  'l',
#  'london',
#  'assembly',
#  'london',
#  'assembly',
#  'constituency',
#  'uk',
#  'parliament',
#  'constituenciesarea',
#  'total',
#  'sq',
#  'mi',
#  'km',
#  'urban',
#  'sq',
#  'mi',
#  'km',
#  'metro',
#  'sq',
#  'mi',
#  'km',
#  'city',
#  'london',
#  'sq',
#  'mi',
#  'km',
#  'london',
#  'borough',
#  'total',
#  'sq',
#  'mi',
#  'km',
#  'elevation',
#  'ft',
#  'population',
#  'except',
#  'stated',
#  'total',
#  'density',
#  'sq',
#  'mi',
#  'km',
#  'urban',
#  'metro',
#  'london',
#  'metropolitan',
#  'area',
#  'city',
#  'london',
#  'demonymslondonergva',
#  'total',
#  'billion',
#  'per',
#  'caput',
#  'time',
#  'zoneutc',
#  'greenwich',
#  'mean',
#  'time',
#  'summer',
#  'dst',
#  'utc',
#  'british',
#  'summer',
#  'time',
#  'postcode',
#  'area',
#  'area',
#  'e',
#  'ec',
#  'n',
#  'nw',
#  'se',
#  'sw',
#  'w',
#  'wc',
#  'br',
#  'cm',
#  'cr',
#  'da',
#  'en',
#  'ha',
#  'ig',
#  'kt',
#  'rm',
#  'sm',
#  'ub',
#  'wd',
#  'tn',
#  'tw',
#  'budget',
#  'billion',
#  'billion',
#  'international',
#  'airportsinside',
#  'london',
#  'heathrow',
#  'lhr',
#  'city',
#  'lcy',
#  'outside',
#  'london',
#  'gatwick',
#  'lgw',
#  'stansted',
#  'stn',
#  'luton',
#  'ltn',
#  'southend',
#  'sen',
#  'rapid',
#  'transit',
#  'systemlondon',
#  'undergroundpolicemetropolitan',
#  'county',
#  'greater',
#  'london',
#  'city',
#  'london',
#  'city',
#  'london',
#  'square',
#  'mile',
#  'ambulancelondonfirelondongeotld',
#  'londonwebsitewww',
#  'london',
#  'gov',
#  'uk',
#  'london',
#  'capital',
#  'largest',
#  'city',
#  'england',
#  'united',
#  'kingdom',
#  'population',
#  'around',
#  'million',
#  'largest',
#  'city',
#  'western',
#  'europe',
#  'metropolitan',
#  'area',
#  'population',
#  'million',
#  'note',
#  'stand',
#  'river',
#  'thames',
#  'south',
#  'east',
#  'england',
#  'head',
#  'mile',
#  'km',
#  'estuary',
#  'north',
#  'sea',
#  'ha',
#  'major',
#  'settlement',
#  'nearly',
#  'two',
#  'millennium',
#  'city',
#  'london',
#  'ancient',
#  'core',
#  'financial',
#  'centre',
#  'wa',
#  'founded',
#  'roman',
#  'londinium',
#  'retains',
#  'medieval',
#  'boundary',
#  'note',
#  'city',
#  'westminster',
#  'west',
#  'city',
#  'london',
#  'ha',
#  'century',
#  'hosted',
#  'national',
#  'government',
#  'parliament',
#  'since',
#  'th',
#  'century',
#  'name',
#  'london',
#  'also',
#  'refers',
#  'metropolis',
#  'around',
#  'core',
#  'historically',
#  'split',
#  'among',
#  'county',
#  'middlesex',
#  'essex',
#  'surrey',
#  'kent',
#  'hertfordshire',
#  'since',
#  'ha',
#  'largely',
#  'comprised',
#  'greater',
#  'london',
#  'governed',
#  'local',
#  'authority',
#  'greater',
#  'london',
#  'authority',
#  'note',
#  'one',
#  'world',
#  'major',
#  'global',
#  'city',
#  'london',
#  'exerts',
#  'strong',
#  'influence',
#  'world',
#  'art',
#  'entertainment',
#  'fashion',
#  'commerce',
#  'finance',
#  'education',
#  'health',
#  'care',
#  'medium',
#  'science',
#  'technology',
#  'tourism',
#  'transport',
#  'communication',
#  'despite',
#  'post',
#  'brexit',
#  'exodus',
#  'stock',
#  'listing',
#  'london',
#  'stock',
#  'exchange',
#  'london',
#  'still',
#  'one',
#  'europe',
#  'economically',
#  'powerful',
#  'city',
#  'remains',
#  'one',
#  'major',
#  'financial',
#  'centre',
#  'world',
#  'europe',
#  'largest',
#  'concentration',
#  'higher',
#  'education',
#  'institution',
#  'home',
#  'highest',
#  'ranked',
#  'academic',
#  'institution',
#  'world',
#  'imperial',
#  'college',
#  'london',
#  'natural',
#  'applied',
#  'science',
#  'london',
#  'school',
#  'economics',
#  'social',
#  'science',
#  'comprehensive',
#  'university',
#  'college',
#  'london',
#  'london',
#  'visited',
#  'city',
#  'europe',
#  'ha',
#  'busiest',
#  'city',
#  'airport',
#  'system',
#  'world',
#  'london',
#  'underground',
#  'oldest',
#  'rapid',
#  'transit',
#  'system',
#  'world',
#  'london',
#  'diverse',
#  'culture',
#  'encompass',
#  'language',
#  'population',
#  'greater',
#  'london',
#  'million',
#  'made',
#  'europe',
#  'third',
#  'populous',
#  'city',
#  'accounting',
#  'population',
#  'united',
#  'kingdom',
#  'population',
#  'england',
#  'greater',
#  'london',
#  'built',
#  'area',
#  'fourth',
#  'populous',
#  'europe',
#  'million',
#  'inhabitant',
#  'census',
#  'london',
#  'metropolitan',
#  'area',
#  'third',
#  'populous',
#  'europe',
#  'million',
#  'inhabitant',
#  'note',
#  'granting',
#  'london',
#  'status',
#  'megacity',
#  'london',
#  'ha',
#  'four',
#  'world',
#  'heritage',
#  'site',
#  'tower',
#  'london',
#  'kew',
#  'garden',
#  'combined',
#  'palace',
#  'westminster',
#  'westminster',
#  'abbey',
#  'st',
#  'margaret',
#  'church',
#  'historic',
#  'settlement',
#  'greenwich',
#  'royal',
#  'observatory',
#  'greenwich',
#  'defines',
#  'prime',
#  'meridian',
#  'longitude',
#  'greenwich',
#  'mean',
#  'time',
#  'landmark',
#  'include',
#  'buckingham',
#  'palace',
#  'london',
#  'eye',
#  'piccadilly',
#  'circus',
#  'st',
#  'paul',
#  'cathedral',
#  'tower',
#  'bridge',
#  'trafalgar',
#  'square',
#  'london',
#  'ha',
#  'many',
#  'museum',
#  'gallery',
#  'library',
#  'cultural',
#  'venue',
#  'including',
#  'british',
#  'museum',
#  'national',
#  'gallery',
#  'natural',
#  'history',
#  'museum',
#  'tate',
#  'modern',
#  'british',
#  'library',
#  'numerous',
#  'west',
#  'end',
#  'theatre',
#  'important',
#  'sporting',
#  'event',
#  'held',
#  'london',
#  'include',
#  'fa',
#  'cup',
#  'final',
#  'wimbledon',
#  'tennis',
#  'championship',
#  'london',
#  'marathon',
#  'london',
#  'became',
#  'first',
#  'city',
#  'host',
#  'three',
#  'summer',
#  'olympic',
#  'game',
#  'toponymy',
#  'main',
#  'article',
#  'etymology',
#  'london',
#  'london',
#  'ancient',
#  'name',
#  'attested',
#  'first',
#  'century',
#  'ad',
#  'usually',
#  'latinised',
#  'form',
#  'londinium',
#  'modern',
#  'scientific',
#  'analysis',
#  'name',
#  'must',
#  'account',
#  'origin',
#  'different',
#  'form',
#  'found',
#  'early',
#  'source',
#  'latin',
#  'usually',
#  'londinium',
#  'old',
#  'english',
#  'usually',
#  'lunden',
#  'welsh',
#  'usually',
#  'llundein',
#  'reference',
#  'known',
#  'development',
#  'time',
#  'sound',
#  'different',
#  'language',
#  'agreed',
#  'name',
#  'came',
#  'language',
#  'common',
#  'brythonic',
#  'recent',
#  'work',
#  'tends',
#  'reconstruct',
#  'lost',
#  'celtic',
#  'form',
#  'name',
#  ...]

# %%
unique_words = set(filtered_tokens)

# %%
unique_words
# Out:
# {'dongguan',
#  'nevil',
#  'belgravia',
#  'brookings',
#  'arch',
#  'trend',
#  'picture',
#  'lister',
#  'tilting',
#  'boost',
#  'articlesengvarb',
#  'zolfagharifard',
#  'gittelson',
#  'natural',
#  'bibliography',
#  'orwell',
#  'billion',
#  'mouse',
#  'pink',
#  'pandemic',
#  'political',
#  'success',
#  'londonevolution',
#  'zazakize',
#  'idref',
#  'die',
#  'employee',
#  'sub',
#  'bermondsey',
#  'administered',
#  'wandle',
#  'anarchy',
#  'mostly',
#  'menu',
#  'birth',
#  'j',
#  'wallace',
#  'ticket',
#  'rim',
#  'globe',
#  'middlesex',
#  'corner',
#  'proceeded',
#  'contributed',
#  'bank',
#  'woolf',
#  'saint',
#  'middle',
#  'baitul',
#  'pub',
#  'tearoom',
#  'pancras',
#  'noted',
#  'manolo',
#  'stanford',
#  'almanac',
#  'budget',
#  'matthew',
#  'intercity',
#  'mobile',
#  'mle',
#  'health',
#  'despite',
#  'encouraged',
#  'bomb',
#  'rainy',
#  'lowest',
#  'billy',
#  'lee',
#  'luck',
#  'slowly',
#  'schofield',
#  'light',
#  'starting',
#  'enterprise',
#  'citywide',
#  'gidea',
#  'airportswithin',
#  'chatham',
#  'cycling',
#  'bike',
#  'rod',
#  'since',
#  'sydney',
#  'fallow',
#  'travel',
#  'growth',
#  'mainly',
#  'strange',
#  'public',
#  'entering',
#  'confused',
#  'illustrator',
#  'officially',
#  'centrenetworkinternational',
#  'aragon',
#  'osprey',
#  'dennis',
#  'desecularisation',
#  'director',
#  'nla',
#  'amsterdam',
#  'business',
#  'stanstedairport',
#  'rd',
#  'collegiate',
#  'travelling',
#  'total',
#  'specifically',
#  'united',
#  'bob',
#  'trinity',
#  'europegreater',
#  'profit',
#  'pageget',
#  'rhyming',
#  'seven',
#  'walton',
#  'zoo',
#  'stevens',
#  'native',
#  'br',
#  'half',
#  'squirrel',
#  'financed',
#  'threat',
#  'toponymy',
#  'piccadilly',
#  'vince',
#  'nova',
#  'commerce',
#  'serotine',
#  'drama',
#  'gregory',
#  'zbekcha',
#  'place',
#  'starred',
#  'order',
#  'newly',
#  'isleworth',
#  'templehistorical',
#  'end',
#  'spring',
#  'sketch',
#  'intersected',
#  'replaced',
#  'imax',
#  'associated',
#  'gunnersbury',
#  'issue',
#  'slasher',
#  'france',
#  'disused',
#  'kovats',
#  'rome',
#  'descriptionshort',
#  'helping',
#  'regent',
#  'wycombe',
#  'waterloo',
#  'georgian',
#  'service',
#  'nelson',
#  'factory',
#  'holiday',
#  'fifa',
#  'dominion',
#  'carshalton',
#  'satellite',
#  'unoccupied',
#  'clockwork',
#  'philharmonic',
#  'usually',
#  'current',
#  'cab',
#  'cilt',
#  'began',
#  'every',
#  'illustration',
#  'oak',
#  'concentration',
#  'simi',
#  'kid',
#  'policy',
#  'oldman',
#  'heat',
#  'hitchin',
#  'circle',
#  'field',
#  'created',
#  'chip',
#  'oxo',
#  'kt',
#  'sunrise',
#  'wiley',
#  'cholera',
#  'subsequently',
#  'empire',
#  'vtetransport',
#  'coronation',
#  'filespecial',
#  'tide',
#  'bridging',
#  'film',
#  'foreign',
#  'suite',
#  'trump',
#  'christie',
#  'sikh',
#  'hilly',
#  'residential',
#  'christianity',
#  'count',
#  'galliano',
#  'warner',
#  'scope',
#  'computer',
#  'buildingspartly',
#  'busy',
#  'noll',
#  'renovate',
#  'structure',
#  'eating',
#  'article',
#  'mid',
#  'petticoat',
#  'enfield',
#  'fictitious',
#  'avalon',
#  'lancashire',
#  'pearson',
#  'wong',
#  'stamp',
#  'hoxton',
#  'hyderabad',
#  'inner',
#  'entertainment',
#  'voted',
#  'relocate',
#  'adrian',
#  'toy',
#  'tertiary',
#  'financier',
#  'sixty',
#  'killed',
#  'phonographic',
#  'montfort',
#  'awarded',
#  'relative',
#  'american',
#  'cheapside',
#  'beatles',
#  'improved',
#  'portssouthern',
#  'czech',
#  'tangled',
#  'distinctive',
#  'online',
#  'shortest',
#  'coming',
#  'sister',
#  'retailingshops',
#  'wapping',
#  'telegraph',
#  'rumoured',
#  'polish',
#  'seen',
#  'plot',
#  'drive',
#  'changed',
#  'geotld',
#  'cfb',
#  'liz',
#  'hangzhou',
#  'stucco',
#  'stadium',
#  'box',
#  'gibbs',
#  'show',
#  'determined',
#  'even',
#  'adam',
#  'wikivoyagedata',
#  'hour',
#  'rail',
#  'joint',
#  'magazine',
#  'sale',
#  'wikidataarticles',
#  'norman',
#  'et',
#  'nation',
#  'ceda',
#  'nathusius',
#  'dulwich',
#  'saxon',
#  'adder',
#  'reduced',
#  'spin',
#  'friday',
#  'dartford',
#  'dna',
#  'rochford',
#  'flag',
#  'yateley',
#  'noctule',
#  'gardiner',
#  'crerar',
#  'purchased',
#  'knmi',
#  'reference',
#  'dubstep',
#  'covered',
#  'scientific',
#  'extends',
#  'tetun',
#  'bromley',
#  'company',
#  'expulsion',
#  'wrote',
#  'bajr',
#  'hoyler',
#  'tmc',
#  'napulitano',
#  'airspace',
#  'codewikidata',
#  'ekistics',
#  'livery',
#  'move',
#  'reform',
#  'victorian',
#  'connection',
#  'rhythm',
#  'bombing',
#  'society',
#  'malin',
#  'walkway',
#  'bletchley',
#  'neverwhere',
#  'sadiq',
#  'irish',
#  'embedded',
#  'israel',
#  'longman',
#  'ocean',
#  'fountain',
#  'tower',
#  'eyenelson',
#  'lcc',
#  'sweeney',
#  'stabbing',
#  'tomorrow',
#  'lamda',
#  'capacity',
#  'ois',
#  'interest',
#  'gothic',
#  'angeles',
#  'meteorological',
#  'founding',
#  'regular',
#  'canada',
#  'spot',
#  'wood',
#  'cartographic',
#  'pdfprintable',
#  'uncodified',
#  'tunnel',
#  'financial',
#  'marginally',
#  'strood',
#  'andr',
#  'contributor',
#  'low',
#  'italian',
#  'countiesgreater',
#  'outskirt',
#  'ukraine',
#  'real',
#  'english',
#  'dominic',
#  'manor',
#  'exemplified',
#  'influence',
#  'sean',
#  'observed',
#  'many',
#  'sandwich',
#  'rotherhithe',
#  'afro',
#  'classified',
#  'projected',
#  'fran',
#  'ia',
#  'significantly',
#  'dalmatian',
#  'symbolic',
#  'visible',
#  'purple',
#  'carriage',
#  'screening',
#  'cindi',
#  'leavesden',
#  'cohen',
#  'borrowed',
#  'tolworth',
#  'coispeau',
#  'smooth',
#  'heatwave',
#  'expensive',
#  'englandshow',
#  'boris',
#  'listcs',
#  'threshold',
#  'located',
#  'circuscanary',
#  'reformation',
#  'christmas',
#  'bnfdata',
#  'toll',
#  'download',
#  'strategic',
#  'leo',
#  'developing',
#  'within',
#  'african',
#  'curiosity',
#  'grinstead',
#  'globaldatalab',
#  'remained',
#  'westminster',
#  'fa',
#  'londoner',
#  'rush',
#  'proceeding',
#  'eventsrandom',
#  'bishop',
#  'hedrick',
#  'depending',
#  'carrier',
#  'joseph',
#  'invaded',
#  'surrounded',
#  'venue',
#  'fortune',
#  'edinburgh',
#  'adele',
#  'michael',
#  'dog',
#  'confetti',
#  'lighter',
#  'essential',
#  'argued',
#  'aerospace',
#  'mirand',
#  'initial',
#  'cadogan',
#  'xi',
#  'dated',
#  'improve',
#  'pop',
#  'demonymslondonergva',
#  'bap',
#  'liberal',
#  'grew',
#  'poultry',
#  'amalgamate',
#  'fair',
#  'sade',
#  'lab',
#  'gorham',
#  'merchant',
#  'croquet',
#  'retail',
#  'radio',
#  'set',
#  'lion',
#  'incarnation',
#  'humidity',
#  'provisional',
#  'framestore',
#  'brisbane',
#  'stella',
#  'winnie',
#  'barbican',
#  'bim',
#  'nd',
#  'work',
#  'rent',
#  'hausahawai',
#  'doi',
#  'food',
#  'hydrological',
#  'aged',
#  'kent',
#  'tends',
#  'alan',
#  'fiction',
#  'bobby',
#  'centralbislama',
#  'scottish',
#  'steven',
#  'meanwhile',
#  'portugu',
#  'wm',
#  'soho',
#  'funded',
#  'cover',
#  'thompson',
#  'core',
#  'expanded',
#  'fish',
#  'appointed',
#  'landmark',
#  'boutique',
#  'mountain',
#  'globalization',
#  'beckton',
#  'beaconsfield',
#  'trendsetter',
#  'ritchie',
#  'canvey',
#  'desmond',
#  'wizz',
#  'andy',
#  'prevailing',
#  'jekyll',
#  'nkc',
#  'conservative',
#  'numan',
#  'susan',
#  'existing',
#  'hammer',
#  'lundenwic',
#  'percent',
#  'geography',
#  'insight',
#  'headquartered',
#  'pageantry',
#  'albert',
#  'house',
#  'tokyo',
#  'na',
#  'addition',
#  'constitution',
#  'mayor',
#  'ideal',
#  'operates',
#  'facto',
#  'dialect',
#  'philharmonia',
#  'slightly',
#  'modernist',
#  'rising',
#  'boishakhi',
#  'helmet',
#  'normal',
#  'mousetrap',
#  'westcombe',
#  'incredible',
#  'include',
#  'specie',
#  'arrives',
#  'important',
#  'lyon',
#  'osaka',
#  'manila',
#  'republican',
#  'citeseerx',
#  'jul',
#  'cloth',
#  'tour',
#  'dawkins',
#  'listed',
#  'dead',
#  'eurostat',
#  'soup',
#  'romanesque',
#  'stationery',
#  'press',
#  'manchester',
#  'widely',
#  'moran',
#  'provided',
#  'crime',
#  'potter',
#  'maintained',
#  'selfridges',
#  'romania',
#  'southbank',
#  'gamesbids',
#  'ngv',
#  'developer',
#  'higher',
#  'plan',
#  'bird',
#  'incorporating',
#  'observatory',
#  'commonwealth',
#  'brick',
#  'football',
#  'benefit',
#  'diverse',
#  'surrounding',
#  'iron',
#  'extension',
#  'plant',
#  'channel',
#  'wealthy',
#  'conduct',
#  'abroad',
#  'namely',
#  'hide',
#  'increasingly',
#  'combined',
#  'barking',
#  'elizabeth',
#  'ub',
#  'sustained',
#  'alperton',
#  'haul',
#  'memorial',
#  'uws',
#  'angling',
#  'crowned',
#  'charity',
#  'sep',
#  'papiamentu',
#  'cowell',
#  'centre',
#  'tonga',
#  'partner',
#  'nikolaus',
#  'lead',
#  'reigate',
#  'londonuniversitiesuniversity',
#  'trumble',
#  'prestigious',
#  'xavier',
#  'wikipedia',
#  'instrument',
#  'difference',
#  'reveal',
#  'archway',
#  'pevsner',
#  'lgbt',
#  'bangladeshi',
#  'athens',
#  'montreal',
#  'foreshore',
#  'paulo',
#  'taylor',
#  'broader',
#  'havering',
#  'seal',
#  'regulation',
#  'fifth',
#  'presented',
#  'expansion',
#  'response',
#  'significant',
#  'martin',
#  'rfu',
#  'britainpopulated',
#  'chi',
#  'arcelormittal',
#  'hygiene',
#  'nursery',
#  'hinduism',
#  'seoul',
#  'athletic',
#  'scotsman',
#  'motor',
#  'agatha',
#  'arcade',
#  'risk',
#  'chigwell',
#  'coordinated',
#  'haywards',
#  'ifs',
#  'ne',
#  'cent',
#  'hamlyn',
#  'hell',
#  'ended',
#  'laor',
#  'franchise',
#  'grant',
#  'good',
#  'collapsed',
#  'incursion',
#  'next',
#  'word',
#  'elephant',
#  'corn',
#  'traditionally',
#  'nlg',
#  'wiktionarymedia',
#  'gay',
#  'anyone',
#  'temperate',
#  'true',
#  'goulding',
#  'marlow',
#  'hamlet',
#  'maint',
#  'bell',
#  'uk',
#  'dignity',
#  'disneyland',
#  'display',
#  'band',
#  'hydrology',
#  'hampstead',
#  'medical',
#  'daniel',
#  'sheeran',
#  'wonderland',
#  'comedy',
#  'pride',
#  'attic',
#  'kaufman',
#  'attenborough',
#  'ioc',
#  'passenger',
#  'clipper',
#  'novel',
#  'visitor',
#  'casweb',
#  'broadgate',
#  'fiji',
#  'failed',
#  'flynn',
#  'respectively',
#  'entered',
#  'extreme',
#  'became',
#  'cavendish',
#  'region',
#  'regain',
#  'themed',
#  'lieutenancy',
#  'five',
#  'operated',
#  'rebuffed',
#  'scattered',
#  'referred',
#  'department',
#  'grow',
#  'sporting',
#  'sometimes',
#  'penguin',
#  'airport',
#  'dropping',
#  'prom',
#  'biography',
#  'mill',
#  'tate',
#  'da',
#  'kingdomlondonlocation',
#  'detective',
#  'fire',
#  'dating',
#  'kv',
#  'gravesend',
#  'consecutive',
#  'st',
#  'summary',
#  'major',
#  'ending',
#  'find',
#  'metropolitan',
#  'tunbridge',
#  'parliament',
#  'badger',
#  'product',
#  'grey',
#  'range',
#  'blackman',
#  'maidenhead',
#  'ftse',
#  'succeeded',
#  'asian',
#  'outright',
#  'table',
#  'dictionary',
#  'kip',
#  'educational',
#  'fox',
#  'olson',
#  'rambert',
#  'restaurant',
#  'alice',
#  'originated',
#  'riverside',
#  'deliberative',
#  'contested',
#  'pickpocket',
#  'inhg',
#  'shared',
#  'blog',
#  'bakerloo',
#  'tribe',
#  'thatcher',
#  'designed',
#  'datastore',
#  'ian',
#  'commute',
#  'overcrowded',
#  'issn',
#  'url',
#  'hand',
#  'assumed',
#  'adding',
#  'mtr',
#  'circular',
#  'sound',
#  'maximum',
#  'southwark',
#  'selected',
#  'watson',
#  'militancy',
#  'gastronomic',
#  'divided',
#  'paul',
#  'dart',
#  'armed',
#  'metroline',
#  'longitude',
#  'computing',
#  'saphora',
#  'super',
#  'digestive',
#  'arriving',
#  'youngest',
#  'olivier',
#  'son',
#  'burnt',
#  'height',
#  'unveiled',
#  'catalogue',
#  'malagasy',
#  'tube',
#  'snowy',
#  'witch',
#  'includes',
#  'santos',
#  'healthcare',
#  'keay',
#  'johnson',
#  'astronomy',
#  'highams',
#  'cornhill',
#  'airline',
#  'speed',
#  'employment',
#  'taken',
#  'lc',
#  'macpherson',
#  'sherlock',
#  'estimate',
#  'bufr',
#  'pea',
#  'wilkins',
#  'strait',
#  'dominant',
#  'harvey',
#  'dia',
#  'premiere',
#  'hundred',
#  'unique',
#  'wealthiest',
#  'engineer',
#  'canon',
#  'hook',
#  'ychi',
#  'sewer',
#  'bulk',
#  'based',
#  'destination',
#  'londonlocation',
#  'arab',
#  'nam',
#  'coupled',
#  'immigration',
#  'census',
#  'china',
#  'reliability',
#  'modern',
#  'vintage',
#  'egerton',
#  'eurostar',
#  'evolved',
#  'large',
#  'mother',
#  'survivor',
#  'synth',
#  'needle',
#  'cityriver',
#  'song',
#  'floyd',
#  'choo',
#  'print',
#  'cityam',
#  'according',
#  'vary',
#  'close',
#  'sinclair',
#  'aylesbury',
#  'letchworth',
#  'provide',
#  'commemorate',
#  'decriminalised',
#  'hold',
#  'advertiser',
#  'cullinan',
#  'linkpage',
#  'third',
#  'greatest',
#  'bart',
#  'sm',
#  'epping',
#  'en',
#  'latter',
#  'pepys',
#  'southeast',
#  'authorised',
#  'nicholas',
#  'worcester',
#  'south',
#  'governance',
#  'julia',
#  'kobe',
#  'across',
#  'knightley',
#  'receive',
#  'washington',
#  'minute',
#  'mortality',
#  'countless',
#  'quant',
#  'maritime',
#  'php',
#  'edmonton',
#  'faka',
#  'undergroundpolicemetropolitan',
#  'bordering',
#  'net',
#  'capitalscapitals',
#  'v',
#  'livingstone',
#  'renaissance',
#  'dorking',
#  'revived',
#  'seller',
#  'admiral',
#  'year',
#  'street',
#  'wetland',
#  'connected',
#  'pinewood',
#  'monty',
#  'aligned',
#  'putney',
#  'commemorating',
#  'nightingale',
#  'luxe',
#  'karimi',
#  'speaker',
#  'megacity',
#  'hale',
#  'ranger',
#  'governed',
#  'consists',
#  'depart',
#  'meaning',
#  'sheriff',
#  'main',
#  'economic',
#  'knightsbridge',
#  'loftus',
#  'route',
#  'changesupload',
#  'liscombe',
#  'majorsports',
#  'comedian',
#  'mori',
#  'ibeji',
#  'date',
#  'spliting',
#  'emerge',
#  'team',
#  'gateway',
#  'court',
#  'liberty',
#  'concise',
#  'enters',
#  'award',
#  'winning',
#  'eastenders',
#  ...}
